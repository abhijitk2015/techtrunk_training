# %% [markdown]
# # Getting started with Images

# %%
# pip install opencv-python

# %%
import cv2
import numpy
import matplotlib.pyplot as plt
import matplotlib.image as im

# %%
# load an image using opencv
img = cv2.imread(r"C:\Users\anshu\Desktop\testlogo.png")

# %%
img.shape
# Out:
# (300, 300, 3)

# %%
img[:,:,1]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
cv2.imshow("my image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)
plt.show()

# %%
img2 = im.imread(r"C:\Users\anshu\Desktop\testlogo.png")
plt.imshow(img2)
plt.show()

# %%
img2.shape
# Out:
# (300, 300, 3)

# %%
# %matplotlib qt
plt.imshow(img)
plt.show()

# %%
# %matplotlib inline
plt.imshow(img2)
plt.show()

# %%
img3 = cv2.imread(r"C:\Python36\images\dhoni125.png",1)
img3.shape
# Out:
# (1240, 1450, 3)

# %%
img4 = cv2.imread(r"C:\Python36\images\dhoni125.png",0)
img4.shape
# Out:
# (1240, 1450)

# %%
plt.imshow(img4,cmap='gray')
plt.show()

# %%
# %matplotlib qt
plt.imshow(img4,cmap='gray')
plt.show()

# %%
# converting BGR to RGB
img5 = cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
plt.imshow(img5)
plt.show()

# %%
# converting BGR to Grayscale
img5 = cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
plt.imshow(img5,cmap='gray')
plt.show()

# %%
# %matplotlib inline
# converting BGR to RGB
img5 = cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
plt.imshow(img5,cmap='gray')
plt.show()

# %%
imp = 0.5*numpy.ones(img3.shape)
img6 = img3+imp
cv2.imshow("my image",imp)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img7=im.imread(r"C:\Python36\images\car2.jpg")
plt.imshow(img7)
plt.show()

# %%
imp = 0.0001*numpy.ones(img7.shape)
img8 = img7+imp
plt.imshow(img8)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(img7)
plt.show()

# %%
img7.shape
# Out:
# (183, 275, 3)

# %%
img9 = img7[20:150,70:250,:]
plt.imshow(img9)
plt.show()

# %%
x = numpy.array([[0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,],
                [255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0],
                [0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,],
                [255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0],
                [0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,],
                [255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0],
                [0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,],
                [255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0],
                [0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,],
                [255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0],
                [0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,],
                [255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0],
                [0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,],
                [255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0],
                [0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,],
                [255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0,255,255,0,0]])
x.shape
# Out:
# (16, 28)

# %%
plt.imshow(x,cmap='gray')
plt.show()
